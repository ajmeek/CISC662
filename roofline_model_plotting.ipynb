# %% [markdown]
# <a href="https://colab.research.google.com/github/ameek2/CISC662/blob/master/roofline_model_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #tpu performance data
# ![image.png](data:image/png;base64,...)

# %%
# tpu performace data
import matplotlib.pyplot as plt

x = [44.54059264, 46.2653147, 61.03132506, 74.44055703, 26.5458961, 155.2603752, 8.424078177, 14.3231105, 6.776135156, 16.01959388]
y = [7.7553, 6.9924, 16.7737, 11.469, 6.7608, 30.9602, 1.4249, 21.0008, 6.1529, 11.4768]

# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.xlabel("Arithmetic Intensity(FLOPs/BYTE)")
plt.ylabel("ATTAINABLE PERFORMANCE (GFLOP/s)")
plt.xticks([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]) 
plt.yticks([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024])
plt.scatter(x, y)
plt.show()

# %%
# tpu performace data
import matplotlib.pyplot as plt

x = [44.54059264, 46.2653147, 61.03132506, 74.44055703, 26.5458961, 155.2603752, 8.424078177, 14.3231105, 6.776135156, 16.01959388]
y = [7.7553, 6.9924, 16.7737, 11.469, 6.7608, 30.9602, 1.4249, 21.0008, 6.1529, 11.4768]

# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.xlabel("Arithmetic Intensity(FLOPs/BYTE)")
plt.ylabel("ATTAINABLE PERFORMANCE (GFLOP/s)")
plt.xlim(0,1024)
plt.xticks([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]) 
plt.ylim(0,1024)
plt.yticks([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024])
plt.scatter(x, y)
plt.show()

# %% [markdown]
# #gpu performance data
# ![image.png](data:image/png;base64,...)

# %%
# gpu performace data
import matplotlib.pyplot as plt

x = [3.873782072, 3.29896459, 7.443766194, 4.843563106, 3.403810174, 10.86079477, 0.730547548, 9.314638296, 0.325808428, 0.330368492]
y = [7.7553, 6.9924, 16.7737, 11.469, 6.7608, 30.9602, 1.4249, 21.0008, 6.1529, 11.4768]

# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)

plt.xlabel("Arithmetic Intensity(FLOPs/BYTE)")
plt.ylabel("ATTAINABLE PERFORMANCE (GFLOP/s)")
plt.scatter(x, y)
plt.show()

# %%
# gpu performace data
import matplotlib.pyplot as plt

x = [3.873782072, 3.29896459, 7.443766194, 4.843563106, 3.403810174, 10.86079477, 0.730547548, 9.314638296, 0.325808428, 0.330368492]
y = [7.7553, 6.9924, 16.7737, 11.469, 6.7608, 30.9602, 1.4249, 21.0008, 6.1529, 11.4768]

plt.xlabel("Arithmetic Intensity(FLOPs/BYTE)")
plt.ylabel("ATTAINABLE PERFORMANCE (GFLOP/s)")
plt.xlim(0,1024)
plt.xticks([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]) 
plt.ylim(0,1024)
plt.yticks([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024])
plt.plot(0,512)
plt.scatter(x, y)
plt.show()
